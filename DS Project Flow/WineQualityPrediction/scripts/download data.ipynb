# %%
# !pip install kaggle
# Out:
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73052 sha256=adff74d84f16dcd52b50236d9a070d18179316e1ee3f846d04e377685acc4a12
#   Stored in directory: c:\users\ed-pc\appdata\local\pip\cache\wheels\29\da\11\144cc25aebdaeb4931b231e25fd34b394e6a5725cbb2f50106
# Successfully built kaggle
# ...

# %%
print(kaggle.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-977d5f3eb28a> in <module>
# ----> 1 print(kaggle.__version__)
#
# AttributeError: module 'kaggle' has no attribute '__version__'

# %%
import kaggle

# %%
# !kaggle datasets download -d rajyellow46/wine-quality
# Out:
# ...
#   0%|          | 0.00/98.0k [00:00<?, ?B/s]
# 100%|##########| 98.0k/98.0k [00:00<00:00, 2.35MB/s]

# %%
from shutil import copyfile
copyfile('wine-quality.zip', './data_external/wine-quality.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-2693adf59847> in <module>
#       1 from shutil import copyfile
# ----> 2 copyfile('wine-quality.zip', './data_external/wine-quality.zip')
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: './data_external/wine-quality.zip'

# %%
import pandas as pd
data = pd.read_csv('wine-quality.zip')
data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...
